# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace = True)
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.drop(['Cabin', 'Fare', 'Embarked','Ticket'], axis = 1, inplace = True )
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch
# 1       0
# 3       0
# 6       0
# 10      1
# 11      0

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df['Sex'].values)
df['Sex'] = le.transform(df['Sex'].values)

df1 = pd.get_dummies(df,drop_first=True)

# %% [markdown]
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# le.fit(df['Sex'].values)
# df['Sex'] = le.transform(df['Sex'].values)
#
# df = pd.get_dummies(df,drop_first=True)

# %%
df1.head()
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 1             2         1       1    0  38.0      1      0
# 3             4         1       1    0  35.0      1      0
# 6             7         0       1    1  54.0      0      0
# 10           11         1       3    0   4.0      1      1
# 11           12         1       1    0  58.0      0      0
#
#     Name_Allison, Master. Hudson Trevor  Name_Allison, Miss. Helen Loraine  \
# 1                                     0                                  0
# 3                                     0                                  0
# 6                                     0                                  0
# 10                                    0                                  0
# 11                                    0                                  0
#
#     Name_Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  ...  \
# 1                                                   0     ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 202 entries, 1 to 889
# Columns: 208 entries, PassengerId to Name_Young, Miss. Marie Grice
# dtypes: float64(1), int32(1), int64(5), uint8(201)
# memory usage: 51.5 KB

# %%
df1.describe()
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   202.000000  202.000000  202.000000  202.000000  202.000000
# mean    455.495050    0.663366    1.198020    0.529703   35.112392
# std     249.704228    0.473732    0.528205    0.500357   14.988475
# min       2.000000    0.000000    1.000000    0.000000    0.920000
# 25%     263.250000    0.000000    1.000000    0.000000   25.000000
# 50%     457.500000    1.000000    1.000000    1.000000   33.500000
# 75%     681.500000    1.000000    1.000000    1.000000   46.750000
# max     890.000000    1.000000    3.000000    1.000000   80.000000
#
#             SibSp       Parch  Name_Allison, Master. Hudson Trevor  \
# count  202.000000  202.000000                            202.00000
# mean     0.445545    0.440594                              0.00495
# std      0.630490    0.732294                              0.07036
# min      0.000000    0.000000                              0.00000
# ...

# %%
df1['Survived'].value_counts()
# Out:
# 1    134
# 0     68
# Name: Survived, dtype: int64

# %%
### sepearting the X and Y

X = df1.loc[:,['Sex']].values
Y = df1.loc[:,['Survived']].values

# %%
Y.shape
# Out:
# (202, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=0,test_size=.25)

# %%
### scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
### model building

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# C:\Users\vishn\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# LogisticRegression()

# %%
Y_pred= model.predict(X_test)

# %%
from sklearn.metrics import  accuracy_score,confusion_matrix

# %%
cnfm = confusion_matrix(Y_test,Y_pred)
cnfm
# Out:
# array([[16,  2],
#        [ 7, 26]], dtype=int64)

# %%
accuracy_score(Y_test,Y_pred)
# Out:
# 0.8235294117647058

# %%
### takes the gender and survived columns

filter_column = df1[['Survived','Sex']]
filter_column
# Out:
#      Survived  Sex
# 1           1    0
# 3           1    0
# 6           0    1
# 10          1    0
# 11          1    0
# ..        ...  ...
# 871         1    0
# 872         0    1
# 879         1    0
# 887         1    0
# 889         1    1
#
# [202 rows x 2 columns]

# %%
filter_column.to_csv('Survived.csv', index= False)
